# %% [markdown]
# # Pyplot Tutorial:

# %% [markdown]
# **matplotlib.pyplot** is a collection of command style functions that make matplotlib work like MATLAB.
#
# Each pyplot function makes some change to a figure: e.g., creates a figure, creates a plotting area in a figure, plots some lines in a plotting area, decorates the plot with labels, etc.

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([2,4, 6, 4])
# we haven't mentioned the x values .and when we don't mention the x axis values then indices are automatically taken by pyplot
plt.ylabel("Numbers")
plt.xlabel('Indices')
plt.title('MyPlot')
plt.show()

# %% [markdown]
# If you provide a single list or array to the plot() command, matplotlib assumes it is a sequence of y values, and automatically generates the x values for you. Since python ranges start with 0, the default x vector has the same length as y but starts with 0. Hence the x data are [0,1,2,3].

# %% [markdown]
# **plot x versus y**

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
# here we gave two lists so the first one is for x axis and the second one is for y axis.
plt.ylabel('squares')
plt.xlabel('numbers')
plt.grid() # grid on

plt.show()

# %% [markdown]
# For every x, y pair of arguments, there is an optional third argument which is the **format string** that indicates the color and line type of the plot.

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro')
# in ro, r means put red colored dots and o means o shaped dots
plt.grid()

plt.show()

# %% [markdown]
# If matplotlib were limited to working with lists, it would be fairly useless for numeric processing. Generally, you will use **numpy arrays**. In fact, all sequences are converted to numpy arrays internally.

# %%
import numpy as np

# %%
import numpy as np
t = np.arange(0., 5., 0.2) 

#blue dashes, red squares and green triangles
plt.plot(t, t**2, 'b--', label='^2')#   'rs',   'g^')
# b means blue and -- means go for dashed line and label means at the top left hand corner
# indicate -- with ^2
plt.plot(t,t**2.2, 'rs', label='^2.2')
# r means red and s means squared
plt.plot(t, t**2.5, 'g^', label='^2.5')
# g means green and ^ means triangle.
plt.grid()
plt.legend() # add legend based on line labels
# legend means what is in the top left hand corner.
plt.show()

# %% [markdown]
# # Controlling line properties

# %% [markdown]
# **use keyword args**

# %%
x = [1, 2, 3, 4]
y = [1, 4, 9, 16]
plt.plot(x, y, linewidth=5.0)
plt.show()

# %% [markdown]
# **use the setp() **

# %%
x1 = [1, 2, 3, 4]
y1 = [1, 4, 9, 16]
x2 = [1, 2, 3, 4]
y2 = [2, 4, 6, 8]
lines = plt.plot(x1, y1, x2, y2)
# in the above line plt.plot will give array of lines
# use keyword args
plt.setp(lines[0], color='r', linewidth=2.0)
# we can set up the properties of each line like this.
# or MATLAB style string value pairs
plt.setp(lines[1], 'color', 'g', 'linewidth', 2.0)

plt.grid()

# %% [markdown]
# # working with multiple figures and axes

# %%
def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)

plt.figure(1)
# The subplot() command specifies numrows, numcols, 
# fignum where fignum ranges from 1 to numrows*numcols.
plt.subplot(211)
# here in subplot(211) 2 is for num of rows,1 is for num of cols, and the next 1 
# is indicating the current number of subplot for which we want to plot currently.
# like here we are plotting for subplot 1
plt.grid()
plt.plot(t1, f(t1), 'b-')
# b is for blue color and - is for line
# here we are plotting for subplot 2.
plt.subplot(212)
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')
# r is for red color and -- is for --
plt.show()

# %%
plt.figure(1)                # the first figure
plt.subplot(211)             # the first subplot in the first figure
plt.plot([1, 2, 3])
plt.subplot(212)             # the second subplot in the first figure
plt.plot([4, 5, 6])


plt.figure(2)                # a second figure
plt.plot([4, 5, 6])          # creates a subplot(111) by default

plt.figure(1)                # figure 1 current; subplot(212) still current
plt.subplot(211)             # make subplot(211) in figure1 current
plt.title('Easy as 1, 2, 3') # subplot 211 title
plt.show()
